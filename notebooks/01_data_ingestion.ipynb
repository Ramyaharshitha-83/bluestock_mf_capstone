# %%
import pandas as pd

fund_master = pd.read_csv("/workspaces/bluestock_mf_capstone/data/raw/01_fund_master.csv")
nav_history = pd.read_csv("/workspaces/bluestock_mf_capstone/data/raw/02_nav_history.csv")
aum_by_fund_house = pd.read_csv("/workspaces/bluestock_mf_capstone/data/raw/03_aum_by_fund_house.csv")
monthly_aum_by_fund_house = pd.read_csv("/workspaces/bluestock_mf_capstone/data/raw/04_monthly_sip_inflows.csv")
category_aum_by_fund_house = pd.read_csv("/workspaces/bluestock_mf_capstone/data/raw/05_category_inflows.csv")
industry_aum_by_fund_house = pd.read_csv("/workspaces/bluestock_mf_capstone/data/raw/06_industry_folio_count.csv")
scheme_aum_by_fund_house = pd.read_csv("/workspaces/bluestock_mf_capstone/data/raw/07_scheme_performance.csv")
investor_type_aum_by_fund_house = pd.read_csv("/workspaces/bluestock_mf_capstone/data/raw/08_investor_transactions.csv")
portfolio_holdings = pd.read_csv("/workspaces/bluestock_mf_capstone/data/raw/09_portfolio_holdings.csv")
benchmark_index = pd.read_csv("/workspaces/bluestock_mf_capstone/data/raw/10_benchmark_indices.csv")

print(fund_master.head())
print(fund_master.columns)

print(nav_history.head())
print(nav_history.columns)

print(aum_by_fund_house.head())
print(aum_by_fund_house.columns)

print(monthly_aum_by_fund_house.head())
print(monthly_aum_by_fund_house.columns)

print(category_aum_by_fund_house.head())
print(category_aum_by_fund_house.columns)

print(industry_aum_by_fund_house.head())
print(industry_aum_by_fund_house.columns)

print(scheme_aum_by_fund_house.head())
print(scheme_aum_by_fund_house.columns)

print(investor_type_aum_by_fund_house.head())
print(investor_type_aum_by_fund_house.columns)

print(portfolio_holdings.head())
print(portfolio_holdings.columns)

print(benchmark_index.head())
print(benchmark_index.columns)

print("All datasets loaded successfully!")
# Out:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# 1   Equity    Large Cap   Direct  2013-01-01              NIFTY 100 TRI
# 2   Equity    Small Cap  Regular  2009-09-09       BSE 250 SmallCap TRI
# 3   Equity    Small Cap   Direct  2013-01-01       BSE 250 SmallCap TRI
# 4     Debt         Gilt  Regular  2000-12-30  CRISIL Dynamic Gilt Index
#
#    expense_ratio_pct  exit_load_pct  min_sip_amount  min_lumpsum_amount  \
# ...

# %%
fund_codes = set(fund_master["amfi_code"])
nav_codes = set(nav_history["amfi_code"])

missing_codes = fund_codes - nav_codes

print("Missing codes:", missing_codes)
# Out:
# Missing codes: set()
# Bad pipe message: %s [b'0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7\r\nHost: localhost:36903\r\nUs', b'-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/148.']
# Bad pipe message: %s [b'0.0 Safari/537.36\r\nAccept-Encoding: gzip, defla']
# Bad pipe message: %s [b', br, zstd\r\nAccept-Language: en-US,en;q=0.9\r\nCache-Control: max-age=0\r\nReferer: https://github.com/\r\nX-Request-ID: ', b'c94027d11b4cef5d4869838eac69d2\r\nX-Real-IP: 122.183.']
# Bad pipe message: %s [b'.167\r\nX-Forwarded-Port: 443\r\nX-Forwarded-Scheme: h']
# Bad pipe message: %s [b'ps\r\nX-Original-URI: /\r\nX-Scheme: https\r\nsec-fetch-site: cross-site\r\nsec-fetch-mode: navigate\r\nsec-fetch-dest: docum']
# Bad pipe message: %s [b't\r\nsec-ch-ua: "Chromium";v="148", "Google Chrome";v="148", "Not/A)Brand";v="99"\r\nsec-ch-ua-mobile: ?']
